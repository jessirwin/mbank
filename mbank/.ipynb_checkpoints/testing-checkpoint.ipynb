# %%
# from mbank.handlers import variable_handler
# mbank/mbank/handlers.py

# %%
from mbank.bank import cbc_bank

# %% [markdown]
# Want to test opening the stochastic bank and testing the variable format change.

# %%
print('open bank in compatible  format')
bank = cbc_bank('m1m2_nonspinning_l1l2', filename = '/home/jessica.irwin/stochbank/brutebank/bns_bank.npy')

# %%
from handlers import variable_handler

# %%
handler = variable_handler()

# %%
handler.is_theta_ok([1,1,50,50], 'm1m2_nonspinning_l1l2')
